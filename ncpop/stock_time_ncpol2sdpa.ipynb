# %%
from ncpol2sdpa import*
import scipy.io as sio
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt 
import pandas as pd
import time

# %%
# Load stock-market data
load_path = 'setting6.mat'
load_data = sio.loadmat(load_path)
seq=flatten(load_data['seq_d0'].tolist())

# output 'stock-market.txt' for Julia script
f=open('stock-market.txt','w')
for ele in seq:
    f.write(str(ele)+'\n')
f.close()

# %%
# Load stock-market data
load_path = 'data/setting6.mat'
load_data = sio.loadmat(load_path)
seq=flatten(load_data['seq_d0'].tolist())

# %%
experiment=open('data/stock_time_PY.csv','w')
experiment=open('data/stock_time_PY.csv','a')
level = 1
# Experiments
for T in range(5,21):
    R=np.zeros(3)
    for r in range(3):
        
        #if (T>15)&(r>1):
        #    continue
        #else:
        start=np.random.randint(0,100,size=1)[0]
        Y=seq[start:start+T]

        # Decision Variables
        G = generate_operators("G", n_vars=1, hermitian=False, commutative=False)[0]
        Fdash = generate_operators("Fdash", n_vars=1, hermitian=False, commutative=False)[0]
        m = generate_operators("m", n_vars=T+1, hermitian=False, commutative=False)
        q = generate_operators("q", n_vars=T, hermitian=False, commutative=False)
        p = generate_operators("p", n_vars=T, hermitian=False, commutative=False)
        f = generate_operators("f", n_vars=T, hermitian=False, commutative=False)

        # Objective
        obj = sum((Y[i]-f[i])**2 for i in range(T)) + 0.01*sum(p[i]**2 for i in range(T)) + 0.01*sum(q[i]**2 for i in range(T)) 

        # Constraints
        ine1 = [f[i] - Fdash*m[i+1] - p[i] for i in range(T)]
        ine2 = [-f[i] + Fdash*m[i+1] + p[i] for i in range(T)]
        ine4 = [m[i+1] - G*m[i] - q[i] for i in range(T)]
        ine5 = [-m[i+1] + G*m[i] + q[i] for i in range(T)]

        ines = ine1+ine2+ine4+ine5

        # Solve the NCPO
        start = time.time()

        sdp = SdpRelaxation(variables = flatten([G,Fdash,f,p,m,q]), verbose = 2)
        sdp.get_relaxation(level, objective=obj, inequalities=ines)

        #if (T<15):
        sdp.solve(solver='mosek')
        #sdp.solve(solver='sdpa', solverparameters={"executable":"sdpa_gmp","executable": "C:\\Users\\zhouq\\Documents\\sdpa7-windows\\sdpa.exe"})
        end = time.time()
        R[r]=end-start
        #else:
            #continue

    #if (T<15):
    print(T,',',np.mean(R),",",np.std(R),file=experiment) #,sdp.n_vars
    #else:
    #    print(" , ,",sdp.n_vars,file=experiment)

experiment.close()
# Out:
# The problem has 23 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 1127
# Generating moment matrix...
# Reduced number of SDP variables: 1127127 (done: 100.09%, ETA 00:00:-0.0)
# Processing 20/20 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1127
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Problem
# Warning: The objective function has a non-zero 4868.15639415 constant term. It is not included in the SDP objective.
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1127
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1127
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 2278
# Factor     - setup time             : 0.03              dense det. time        : 0.00
# Factor     - ML order time          : 0.03              GP order time          : 0.00
# Factor     - nonzeros before factor : 6.36e+05          after factor           : 6.36e+05
# Factor     - dense dim.             : 0                 flops                  : 4.83e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.3e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.05
# 1   3.1e-02  4.9e-04  3.7e-02  -9.99e-01  1.445784622e+03   2.888005686e+03   4.9e-04  0.13
# 2   6.5e-04  1.0e-05  3.8e-03  -7.31e-01  2.472255541e+04   5.867053079e+04   1.0e-05  0.19
# 3   3.7e-06  5.9e-08  4.8e-04  -9.48e-01  8.493098307e+06   2.466376874e+07   5.9e-08  0.23
# 4   4.0e-12  6.7e-14  3.4e-07  -1.00e+00  3.683260935e+12   1.066641586e+13   6.4e-14  0.30
# Optimizer terminated. Time: 0.30
#
# The problem has 23 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 1127
# Generating moment matrix...
# Reduced number of SDP variables: 1127127 (done: 100.09%, ETA 00:00:-0.0)
# Processing 20/20 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1127
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1127
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1127
# Optimizer  - Cones                  : 0
# Warning: The objective function has a non-zero 5380.231854639999 constant term. It is not included in the SDP objective.
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 2278
# Factor     - setup time             : 0.03              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 6.36e+05          after factor           : 6.36e+05
# Factor     - dense dim.             : 0                 flops                  : 4.83e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.7e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.05
# 1   3.0e-02  4.4e-04  3.5e-02  -1.00e+00  1.596697387e+03   3.189831362e+03   4.4e-04  0.11
# 2   6.2e-04  9.3e-06  3.6e-03  -7.31e-01  2.727674071e+04   6.473442050e+04   9.3e-06  0.17
# 3   3.6e-06  5.4e-08  4.5e-04  -9.48e-01  9.352777320e+06   2.716532197e+07   5.4e-08  0.23
# 4   4.0e-12  6.2e-14  3.2e-07  -1.00e+00  4.029900718e+12   1.167226400e+13   5.9e-14  0.30
# Optimizer terminated. Time: 0.31
#
# The problem has 23 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 1127
# Generating moment matrix...
# Reduced number of SDP variables: 1127127 (done: 100.09%, ETA 00:00:-0.0)
# Processing 20/20 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1127
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1127
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1127
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 2278
# Factor     - setup time             : 0.03              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 6.36e+05          after factor           : 6.36e+05
# Factor     - dense dim.             : 0                 flops                  : 4.83e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   7.1e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.05
# Warning: The objective function has a non-zero 6028.39072515 constant term. It is not included in the SDP objective.
# 1   2.8e-02  4.0e-04  3.3e-02  -1.00e+00  1.787715269e+03   3.571867257e+03   4.0e-04  0.13
# 2   5.9e-04  8.3e-06  3.4e-03  -7.31e-01  3.050976944e+04   7.240993771e+04   8.3e-06  0.17
# 3   3.4e-06  4.8e-08  4.3e-04  -9.48e-01  1.044126360e+07   3.033263382e+07   4.8e-08  0.25
# 4   3.9e-12  5.5e-14  3.1e-07  -1.00e+00  4.468880717e+12   1.294600771e+13   5.3e-14  0.31
# Optimizer terminated. Time: 0.31
#
# The problem has 27 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 1539
# Generating moment matrix...
# Reduced number of SDP variables: 1539539 (done: 100.06%, ETA 00:00:-0.0)
# Processing 24/24 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1539
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.02
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Warning: The objective function has a non-zero 5789.5145166699995 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1539
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1539
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 3160
# Factor     - setup time             : 0.08              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.19e+06          after factor           : 1.19e+06
# Factor     - dense dim.             : 0                 flops                  : 1.23e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.3e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.09
# 1   2.6e-02  4.1e-04  3.4e-02  -1.00e+00  1.718363512e+03   3.433163290e+03   4.1e-04  0.20
# 2   4.1e-04  6.6e-06  3.0e-03  -7.43e-01  3.687097869e+04   8.900713998e+04   6.6e-06  0.30
# 3   1.3e-06  2.1e-08  2.8e-04  -9.64e-01  2.352048953e+07   6.772721009e+07   2.1e-08  0.41
# 4   1.3e-13  3.6e-15  2.3e-08  -1.00e+00  1.296875622e+14   3.732313700e+14   1.8e-15  0.52
# Optimizer terminated. Time: 0.52
#
# The problem has 27 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 1539
# Generating moment matrix...
# Reduced number of SDP variables: 1539539 (done: 100.06%, ETA 00:00:-0.0)
# Processing 24/24 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1539
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
# Warning: The objective function has a non-zero 6413.185742799999 constant term. It is not included in the SDP objective.
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1539
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1539
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 3160
# Factor     - setup time             : 0.09              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.19e+06          after factor           : 1.19e+06
# Factor     - dense dim.             : 0                 flops                  : 1.23e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.7e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.09
# 1   2.5e-02  3.7e-04  3.2e-02  -1.00e+00  1.902164627e+03   3.800765659e+03   3.7e-04  0.20
# 2   4.0e-04  5.9e-06  2.9e-03  -7.43e-01  4.077295341e+04   9.842958055e+04   5.9e-06  0.30
# 3   1.3e-06  1.9e-08  2.7e-04  -9.64e-01  2.596427912e+07   7.477732884e+07   1.9e-08  0.41
# 4   1.1e-13  3.2e-15  3.4e-08  -1.00e+00  1.412770123e+14   4.066554369e+14   1.7e-15  0.52
# Optimizer terminated. Time: 0.53
#
# The problem has 27 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 1539
# Generating moment matrix...
# Reduced number of SDP variables: 1539539 (done: 100.06%, ETA 00:00:-0.0)
# Processing 24/24 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1539
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Warning: The objective function has a non-zero 5670.75732448 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1539
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1539
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 3160
# Factor     - setup time             : 0.09              dense det. time        : 0.00
# Factor     - ML order time          : 0.06              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.19e+06          after factor           : 1.19e+06
# Factor     - dense dim.             : 0                 flops                  : 1.23e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.2e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.09
# 1   2.6e-02  4.2e-04  3.4e-02  -1.00e+00  1.683364716e+03   3.363165667e+03   4.2e-04  0.22
# 2   4.2e-04  6.7e-06  3.0e-03  -7.43e-01  3.612796018e+04   8.721290783e+04   6.7e-06  0.33
# 3   1.3e-06  2.2e-08  2.8e-04  -9.64e-01  2.305527652e+07   6.638507717e+07   2.2e-08  0.45
# 4   1.4e-13  3.9e-15  7.2e-08  -1.00e+00  1.274857698e+14   3.668809502e+14   1.9e-15  0.56
# Optimizer terminated. Time: 0.58
#
# The problem has 31 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 2015
# Generating moment matrix...
# Reduced number of SDP variables: 2015015 (done: 100.05%, ETA 00:00:-0.0)
# Processing 28/28 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2015
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Warning: The objective function has a non-zero 7495.812893689999 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2015
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 2015
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 4186
# Factor     - setup time             : 0.16              dense det. time        : 0.00
# Factor     - ML order time          : 0.09              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.03e+06          after factor           : 2.03e+06
# Factor     - dense dim.             : 0                 flops                  : 2.74e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.7e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.17
# 1   2.1e-02  3.2e-04  3.0e-02  -1.00e+00  2.222268463e+03   4.440973183e+03   3.2e-04  0.34
# 2   2.6e-04  3.9e-06  2.3e-03  -7.55e-01  5.957983098e+04   1.458883122e+05   3.9e-06  0.53
# 3   5.1e-07  7.7e-09  1.7e-04  -9.75e-01  6.359059809e+07   1.817274731e+08   7.7e-09  0.72
# 4   2.7e-12  4.2e-13  9.1e-09  -1.00e+00  4.778234411e-01   1.365466395e+00   4.2e-13  0.83
# Optimizer terminated. Time: 0.83
#
# The problem has 31 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 2015
# Generating moment matrix...
# Reduced number of SDP variables: 2015015 (done: 100.05%, ETA 00:00:-0.0)
# Processing 28/28 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2015
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Warning: The objective function has a non-zero 6577.67643489 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2015
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 2015
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 4186
# Factor     - setup time             : 0.16              dense det. time        : 0.00
# Factor     - ML order time          : 0.09              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.03e+06          after factor           : 2.03e+06
# Factor     - dense dim.             : 0                 flops                  : 2.74e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.2e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.17
# 1   2.2e-02  3.6e-04  3.2e-02  -1.00e+00  1.951687004e+03   3.899810088e+03   3.6e-04  0.36
# 2   2.7e-04  4.4e-06  2.4e-03  -7.55e-01  5.239887519e+04   1.283003152e+05   4.4e-06  0.53
# 3   5.4e-07  8.7e-09  1.8e-04  -9.75e-01  5.602117337e+07   1.600642337e+08   8.7e-09  0.70
# 4   2.9e-12  4.7e-13  9.6e-09  -1.00e+00  4.779003965e-01   1.365417695e+00   4.7e-13  0.80
# Optimizer terminated. Time: 0.81
#
# The problem has 31 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 2015
# Generating moment matrix...
# Reduced number of SDP variables: 2015015 (done: 100.05%, ETA 00:00:-0.0)
# Processing 28/28 constraints...
# Warning: The objective function has a non-zero 7622.22163714 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2015
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2015
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 2015
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 4186
# Factor     - setup time             : 0.16              dense det. time        : 0.00
# Factor     - ML order time          : 0.11              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.03e+06          after factor           : 2.03e+06
# Factor     - dense dim.             : 0                 flops                  : 2.74e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.7e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.17
# 1   2.1e-02  3.1e-04  3.0e-02  -1.00e+00  2.259521945e+03   4.515480165e+03   3.1e-04  0.36
# 2   2.6e-04  3.8e-06  2.3e-03  -7.55e-01  6.056848734e+04   1.483097849e+05   3.8e-06  0.55
# 3   5.0e-07  7.5e-09  1.7e-04  -9.75e-01  6.463307368e+07   1.847108962e+08   7.5e-09  0.70
# 4   2.7e-12  4.1e-13  9.0e-09  -1.00e+00  4.778144984e-01   1.365472312e+00   4.1e-13  0.81
# Optimizer terminated. Time: 0.81
#
# The problem has 35 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 2555
# Generating moment matrix...
# Reduced number of SDP variables: 2555555 (done: 100.04%, ETA 00:00:-0.0)
# Processing 32/32 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2555
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Warning: The objective function has a non-zero 7742.03359355 constant term. It is not included in the SDP objective.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2555
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 2555
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 5356
# Factor     - setup time             : 0.31              dense det. time        : 0.00
# Factor     - ML order time          : 0.20              GP order time          : 0.00
# Factor     - nonzeros before factor : 3.27e+06          after factor           : 3.27e+06
# Factor     - dense dim.             : 0                 flops                  : 5.59e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.4e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.34
# 1   2.0e-02  3.1e-04  3.0e-02  -1.00e+00  2.295874777e+03   4.588185548e+03   3.1e-04  0.64
# 2   1.9e-04  2.9e-06  2.0e-03  -7.65e-01  7.665855599e+04   1.899121405e+05   2.9e-06  0.92
# 3   9.6e-07  1.5e-08  2.3e-04  -9.82e-01  3.338055562e+07   9.463198916e+07   1.5e-08  1.16
# 4   8.5e-12  7.3e-13  1.1e-08  -1.00e+00  4.986335934e-01   1.413561738e+00   7.3e-13  1.33
# Optimizer terminated. Time: 1.33
#
# The problem has 35 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 2555
# Generating moment matrix...
# Reduced number of SDP variables: 2555555 (done: 100.04%, ETA 00:00:-0.0)
# Processing 32/32 constraints...
# Warning: The objective function has a non-zero 7533.57442465 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2555
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2555
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 2555
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 5356
# Factor     - setup time             : 0.42              dense det. time        : 0.00
# Factor     - ML order time          : 0.31              GP order time          : 0.00
# Factor     - nonzeros before factor : 3.27e+06          after factor           : 3.27e+06
# Factor     - dense dim.             : 0                 flops                  : 5.59e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.2e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.44
# 1   2.0e-02  3.2e-04  3.0e-02  -1.00e+00  2.234439796e+03   4.465315547e+03   3.2e-04  0.78
# 2   1.8e-04  3.0e-06  2.0e-03  -7.65e-01  7.463116201e+04   1.848880820e+05   3.0e-06  1.16
# 3   9.5e-07  1.5e-08  2.4e-04  -9.82e-01  3.246152129e+07   9.202289470e+07   1.5e-08  1.48
# 4   8.4e-12  7.5e-13  1.1e-08  -1.00e+00  4.986727072e-01   1.413616074e+00   7.5e-13  1.69
# Optimizer terminated. Time: 1.69
#
# The problem has 35 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 2555
# Generating moment matrix...
# Reduced number of SDP variables: 2555555 (done: 100.04%, ETA 00:00:-0.0)
# Processing 32/32 constraints...
# Problem
# Warning: The objective function has a non-zero 7741.7738350399995 constant term. It is not included in the SDP objective.
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2555
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2555
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 2555
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 5356
# Factor     - setup time             : 0.38              dense det. time        : 0.00
# Factor     - ML order time          : 0.27              GP order time          : 0.00
# Factor     - nonzeros before factor : 3.27e+06          after factor           : 3.27e+06
# Factor     - dense dim.             : 0                 flops                  : 5.59e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.3e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.39
# 1   1.9e-02  3.1e-04  3.0e-02  -1.00e+00  2.295798224e+03   4.588032441e+03   3.1e-04  0.72
# 2   1.8e-04  2.9e-06  2.0e-03  -7.65e-01  7.665602968e+04   1.899058800e+05   2.9e-06  1.01
# 3   9.4e-07  1.5e-08  2.3e-04  -9.82e-01  3.337941045e+07   9.462873811e+07   1.5e-08  1.26
# 4   8.3e-12  7.3e-13  1.1e-08  -1.00e+00  4.986336407e-01   1.413561804e+00   7.3e-13  1.47
# Optimizer terminated. Time: 1.47
#
# The problem has 39 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 3159
# Generating moment matrix...
# Reduced number of SDP variables: 3159159 (done: 100.03%, ETA 00:00:-0.0)
# Processing 36/36 constraints...
# Warning: The objective function has a non-zero 8674.36160193 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 3159
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 3159
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 3159
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 6670
# Factor     - setup time             : 0.67              dense det. time        : 0.00
# Factor     - ML order time          : 0.47              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.99e+06          after factor           : 4.99e+06
# Factor     - dense dim.             : 0                 flops                  : 1.05e+10
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.3e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.69
# 1   1.7e-02  2.8e-04  2.8e-02  -1.00e+00  2.571679911e+03   5.139795693e+03   2.8e-04  1.19
# 2   1.3e-04  2.0e-06  1.6e-03  -7.74e-01  1.061020259e+05   2.653781796e+05   2.0e-06  1.66
# 3   1.3e-06  2.1e-08  3.0e-04  -9.87e-01  2.752607824e+07   7.743368480e+07   2.1e-08  2.06
# 4   5.9e-13  1.1e-14  1.1e-07  -1.00e+00  3.085433586e+13   8.667886530e+13   8.6e-15  2.48
# Optimizer terminated. Time: 2.48
#
# The problem has 39 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 3159
# Generating moment matrix...
# Reduced number of SDP variables: 3159159 (done: 100.03%, ETA 00:00:-0.0)
# Processing 36/36 constraints...
# Warning: The objective function has a non-zero 10666.65660847 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 3159
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 3159
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 3159
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 6670
# Factor     - setup time             : 0.66              dense det. time        : 0.00
# Factor     - ML order time          : 0.42              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.99e+06          after factor           : 4.99e+06
# Factor     - dense dim.             : 0                 flops                  : 1.05e+10
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   7.0e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.66
# 1   1.7e-02  2.4e-04  2.6e-02  -1.00e+00  2.986584073e+03   5.969967253e+03   2.4e-04  1.16
# 2   1.3e-04  1.8e-06  1.5e-03  -7.75e-01  1.297562983e+05   3.148268648e+05   1.8e-06  1.61
# 3   2.9e-07  4.2e-09  1.2e-04  -9.87e-01  1.292728304e+08   3.450599097e+08   4.2e-09  2.06
# 4   8.0e-13  3.1e-14  9.6e-10  -1.00e+00  5.376484606e-01   1.435107632e+00   2.9e-14  2.41
# Optimizer terminated. Time: 2.42
#
# The problem has 39 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 3159
# Generating moment matrix...
# Reduced number of SDP variables: 3159159 (done: 100.03%, ETA 00:00:-0.0)
# Processing 36/36 constraints...
# Warning: The objective function has a non-zero 10142.96602489 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 3159
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 3159
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 3159
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 6670
# Factor     - setup time             : 0.66              dense det. time        : 0.00
# Factor     - ML order time          : 0.45              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.99e+06          after factor           : 4.99e+06
# Factor     - dense dim.             : 0                 flops                  : 1.05e+10
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.8e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.67
# 1   1.7e-02  2.5e-04  2.7e-02  -1.00e+00  2.890184576e+03   5.777147245e+03   2.5e-04  1.08
# 2   1.2e-04  1.8e-06  1.6e-03  -7.75e-01  1.239157536e+05   3.034215720e+05   1.8e-06  1.53
# 3   4.9e-07  7.2e-09  1.6e-04  -9.87e-01  7.371643705e+07   1.997838887e+08   7.2e-09  1.94
# 4   1.9e-12  7.3e-14  1.6e-09  -1.00e+00  5.318430848e-01   1.441378446e+00   7.1e-14  2.27
# Optimizer terminated. Time: 2.27
#
# The problem has 43 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 3827
# Generating moment matrix...
# Reduced number of SDP variables: 3827827 (done: 100.03%, ETA 00:00:-0.0)
# Processing 40/40 constraints...
# Warning: The objective function has a non-zero 11666.256688039997 constant term. It is not included in the SDP objective.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 3827
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 3827
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 3827
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 8128
# Factor     - setup time             : 0.97              dense det. time        : 0.00
# Factor     - ML order time          : 0.67              GP order time          : 0.00
# Factor     - nonzeros before factor : 7.32e+06          after factor           : 7.32e+06
# Factor     - dense dim.             : 0                 flops                  : 1.87e+10
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   7.0e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.98
# 1   1.6e-02  2.2e-04  2.5e-02  -1.00e+00  3.231986532e+03   6.461067069e+03   2.2e-04  1.66
# 2   9.1e-05  1.3e-06  1.3e-03  -7.84e-01  1.742357766e+05   4.240081327e+05   1.3e-06  2.31
# 3   4.3e-07  6.2e-09  1.5e-04  -9.91e-01  8.969921457e+07   2.369782814e+08   6.2e-09  2.94
# 4   4.7e-13  3.4e-14  7.2e-10  -1.00e+00  5.581439144e-01   1.474568660e+00   3.2e-14  3.47
# Optimizer terminated. Time: 3.47
#
# The problem has 43 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 3827
# ...
# Factor     - nonzeros before factor : 8.09e+07          after factor           : 8.09e+07
# Factor     - dense dim.             : 0                 flops                  : 6.87e+11
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   7.1e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  11.89
# 1   8.2e-03  1.2e-04  1.8e-02  -1.00e+00  6.253512938e+03   1.250412704e+04   1.2e-04  23.88
# 2   1.1e-05  1.6e-07  4.5e-04  -8.39e-01  1.342221797e+06   3.370899075e+06   1.6e-07  36.94
# 3   2.7e-08  3.8e-10  4.4e-05  -9.99e-01  2.160409521e+09   5.494546142e+09   3.8e-10  50.75
# 4   2.1e-13  1.2e-14  1.0e-09  -1.00e+00  5.956376714e-01   1.514856217e+00   9.8e-15  62.52
# Optimizer terminated. Time: 62.61
#
# The problem has 79 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 12719
# Generating moment matrix...
# Reduced number of SDP variables: 12719719 (done: 100.01%, ETA 00:00:-0.0)
# Processing 63/76 constraints...
# Warning: The objective function has a non-zero 18605.094233260003 constant term. It is not included in the SDP objective.
# Processing 76/76 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 12719
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 12719
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 12719
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 27730
# Factor     - setup time             : 11.67             dense det. time        : 0.00
# Factor     - ML order time          : 7.95              GP order time          : 0.00
# Factor     - nonzeros before factor : 8.09e+07          after factor           : 8.09e+07
# Factor     - dense dim.             : 0                 flops                  : 6.87e+11
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.5e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  11.70
# 1   8.6e-03  1.3e-04  1.9e-02  -1.00e+00  5.415386804e+03   1.082782124e+04   1.3e-04  23.41
# 2   1.3e-05  2.0e-07  5.2e-04  -8.39e-01  1.007731659e+06   2.608930807e+06   2.0e-07  35.98
# 3   1.7e-08  2.7e-10  3.3e-05  -9.99e-01  2.343973784e+09   6.115967896e+09   2.7e-10  48.94
# 4   1.0e-13  5.6e-15  8.2e-10  -1.00e+00  5.727182473e-01   1.494340348e+00   3.6e-15  60.70
# Optimizer terminated. Time: 60.80
#
# The problem has 79 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 12719
# Generating moment matrix...
# Reduced number of SDP variables: 12719719 (done: 100.01%, ETA 00:00:-0.0)
# Processing 60/76 constraints...
# Warning: The objective function has a non-zero 20855.178003400008 constant term. It is not included in the SDP objective.
# Processing 76/76 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 12719
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 12719
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 12719
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 27730
# Factor     - setup time             : 12.03             dense det. time        : 0.00
# Factor     - ML order time          : 8.30              GP order time          : 0.00
# Factor     - nonzeros before factor : 8.09e+07          after factor           : 8.09e+07
# Factor     - dense dim.             : 0                 flops                  : 6.87e+11
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.8e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  12.08
# 1   8.2e-03  1.2e-04  1.9e-02  -1.00e+00  5.918783067e+03   1.183463722e+04   1.2e-04  24.03
# 2   1.2e-05  1.8e-07  4.9e-04  -8.39e-01  1.241098416e+06   3.169585470e+06   1.8e-07  36.67
# 3   5.7e-09  8.4e-11  1.6e-05  -9.99e-01  5.562887992e+09   1.431193219e+10   8.4e-11  56.53
# 4   6.3e-12  3.4e-15  1.4e-06  -1.00e+00  4.226252743e+15   1.080494672e+16   7.7e-17  72.22
# Optimizer terminated. Time: 72.27
#
# The problem has 83 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 14027
# Generating moment matrix...
# Reduced number of SDP variables: 14027027 (done: 100.01%, ETA 00:00:-0.0)
# Processing 48/80 constraints...
# Warning: The objective function has a non-zero 20527.346189760003 constant term. It is not included in the SDP objective.
# Processing 80/80 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 14027
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 14027
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 14027
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 30628
# Factor     - setup time             : 15.97             dense det. time        : 0.00
# Factor     - ML order time          : 11.14             GP order time          : 0.00
# Factor     - nonzeros before factor : 9.84e+07          after factor           : 9.84e+07
# Factor     - dense dim.             : 0                 flops                  : 9.21e+11
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.8e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  16.02
# 1   8.3e-03  1.2e-04  1.9e-02  -1.00e+00  5.825918881e+03   1.164890894e+04   1.2e-04  31.38
# 2   1.1e-05  1.6e-07  4.6e-04  -8.43e-01  1.300981355e+06   3.331949388e+06   1.6e-07  48.11
# 3   2.0e-08  3.0e-10  3.0e-05  -1.00e+00  1.615858334e+09   4.162303890e+09   3.0e-10  64.20
# 4   1.9e-12  3.3e-15  2.3e-07  -1.00e+00  9.294915879e+14   2.383388810e+15   3.1e-16  81.73
# Optimizer terminated. Time: 81.80
#
# The problem has 83 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 14027
# Generating moment matrix...
# Reduced number of SDP variables: 14027027 (done: 100.01%, ETA 00:00:-0.0)
# Processing 54/80 constraints...
# Warning: The objective function has a non-zero 19088.429544979997 constant term. It is not included in the SDP objective.
# Processing 80/80 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 14027
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 14027
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 14027
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 30628
# Factor     - setup time             : 15.44             dense det. time        : 0.00
# Factor     - ML order time          : 10.20             GP order time          : 0.00
# Factor     - nonzeros before factor : 9.84e+07          after factor           : 9.84e+07
# Factor     - dense dim.             : 0                 flops                  : 9.21e+11
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.3e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  15.48
# 1   7.9e-03  1.3e-04  1.9e-02  -1.00e+00  5.611472685e+03   1.121998352e+04   1.3e-04  33.53
# 2   1.1e-05  1.8e-07  5.1e-04  -8.44e-01  1.246443322e+06   3.254615882e+06   1.8e-07  52.48
# 3   6.7e-10  1.1e-11  6.4e-06  -1.00e+00  5.750165927e+10   1.500577041e+11   1.1e-11  71.45
# 4   3.0e-13  3.1e-15  8.8e-10  -1.00e+00  5.704373350e-01   1.488576718e+00   5.6e-16  88.09
# Optimizer terminated. Time: 88.19
#
# The problem has 83 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 14027
# Generating moment matrix...
# Reduced number of SDP variables: 14027027 (done: 100.01%, ETA 00:00:-0.0)
# Processing 57/80 constraints...
# Warning: The objective function has a non-zero 23494.0103216 constant term. It is not included in the SDP objective.
# Processing 80/80 constraints...
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 14027
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 14027
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 14027
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 30628
# Factor     - setup time             : 14.52             dense det. time        : 0.00
# Factor     - ML order time          : 9.86              GP order time          : 0.00
# Factor     - nonzeros before factor : 9.84e+07          after factor           : 9.84e+07
# Factor     - dense dim.             : 0                 flops                  : 9.21e+11
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   7.0e+01  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  14.56
# 1   7.9e-03  1.1e-04  1.8e-02  -1.00e+00  6.487219872e+03   1.297153575e+04   1.1e-04  30.25
# 2   9.7e-06  1.4e-07  4.3e-04  -8.43e-01  1.644314556e+06   4.151872649e+06   1.4e-07  48.27
# 3   2.7e-09  3.8e-11  1.1e-05  -1.00e+00  1.273726225e+10   3.232202494e+10   3.8e-11  65.50
# 4   1.3e-11  2.9e-15  2.6e-07  -1.00e+00  1.399893022e+15   3.524615138e+15   2.1e-16  82.25
# Optimizer terminated. Time: 82.31
